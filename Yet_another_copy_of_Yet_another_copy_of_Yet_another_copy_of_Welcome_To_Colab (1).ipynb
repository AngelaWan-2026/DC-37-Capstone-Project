# %%
#DC-37 Capstone Project  - Analyze NYC OpenData - New York City Restaurants Inspection Analysis

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline



#Load data set

df = pd.read_csv("/content/NYC_Restaurant_Inspection_Results_20260.428.csv")
# Out:
# /tmp/ipykernel_5698/2120153734.py:13: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/NYC_Restaurant_Inspection_Results_20260.428.csv")

# %%
#Display first 10 rows of raw data

df.head(10)
# Out:
#       CAMIS                                             DBA       BORO  \
# 0  50174294                                       FIVE GUYS  Manhattan
# 1  50177452                                           KETTL   Brooklyn
# 2  50181336                                     JADE RABBIT  Manhattan
# 3  50104509              CHELSEA PIERS GOLF BAR AND LOUNGEQ  Manhattan
# 4  50150842                          CEGM (CONNECTOR LEVEL)     Queens
# 5  50180235  GREAT PERFORMANCES/ARTISTS AS WAITRESSES, INC.  Manhattan
# 6  50117880                               FOOD LOVER BAKERY   Brooklyn
# 7  50182163                             SAMRAH COFFEE CORP.     Queens
# 8  50182002                          AUNTIE ANNE'S/CINNABON      Bronx
# 9  50117478                                   SUNSET BAGELS   Brooklyn
#
#     BUILDING             STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0        144           8 AVENUE  10011.0  5184079114                 NaN
# 1         38      NORMAN AVENUE  11222.0  9179090105                 NaN
# 2         32   WEST   48 STREET  10036.0  9176884228                 NaN
# 3        NaN      CHELSEA PIERS  10011.0  2123366831                 NaN
# 4  LAGUARDIA            AIRPORT  11369.0  2159970667                 NaN
# 5          9   WEST   57 STREET  10019.0  2123376092                 NaN
# 6       6305          20 AVENUE  11204.0  6463015998             Chinese
# 7      24-09    STEINWAY STREET  11103.0  3474006350                 NaN
# 8        203  EAST FORDHAM ROAD  10458.0  7863690471                 NaN
# 9       8624           5 AVENUE  11209.0  7188228233            American
#
#   INSPECTION DATE                             ACTION  ...  \
# 0      01/01/1900                                NaN  ...
# 1      01/01/1900                                NaN  ...
# 2      01/01/1900                                NaN  ...
# 3      01/01/1900                                NaN  ...
# 4      01/01/1900                                NaN  ...
# 5      01/01/1900                                NaN  ...
# 6      12/19/2025  Establishment re-opened by DOHMH.  ...
# 7      01/01/1900                                NaN  ...
# 8      01/01/1900                                NaN  ...
# 9      01/18/2024  Establishment re-opened by DOHMH.  ...
#
#                            INSPECTION TYPE   Latitude  Longitude  \
# 0                                      NaN  40.741746 -74.001057
# 1                                      NaN  40.724650 -73.954069
# 2                                      NaN  40.757971 -73.979783
# 3                                      NaN        NaN        NaN
# 4                                      NaN        NaN        NaN
# 5                                      NaN  40.763248 -73.974633
# 6  Cycle Inspection / Reopening Inspection  40.617491 -73.984832
# 7                                      NaN  40.768681 -73.911063
# 8                                      NaN  40.862410 -73.896733
# 9  Cycle Inspection / Reopening Inspection  40.621283 -74.026400
#
#    Community Board Council District Census Tract        BIN           BBL  \
# 0            104.0              3.0       8100.0  1013844.0  1.007670e+09
# 1            301.0             33.0      56900.0  3065946.0  3.026430e+09
# 2            105.0              4.0       9600.0  1000000.0  1.012630e+09
# 3              NaN              NaN          NaN        NaN           NaN
# 4              NaN              NaN          NaN        NaN           NaN
# 5            105.0              4.0      11201.0  1035071.0  1.012730e+09
# 6            311.0             43.0      25400.0  3133259.0  3.055420e+09
# 7            401.0             22.0      14100.0  4011504.0  4.006860e+09
# 8            207.0             15.0      39901.0  2013607.0  2.031540e+09
# 9            310.0             47.0      16000.0  3153556.0  3.060450e+09
#
#     NTA                                  Location
# 0  MN13  POINT (-74.001057357126 40.741745617836)
# 1  BK76  POINT (-73.954069120233 40.724650265888)
# 2  MN17   POINT (-73.97978257519 40.757970868284)
# 3   NaN                                       NaN
# 4   NaN                                       NaN
# 5  MN17   POINT (-73.97463325396 40.763248016082)
# 6  BK28  POINT (-73.984832045497 40.617491406448)
# 7  QN70  POINT (-73.911062890941 40.768681172713)
# 8  BX05  POINT (-73.896732537976 40.862410460591)
# 9  BK31  POINT (-74.026400446045 40.621282660059)
#
# [10 rows x 27 columns]

# %%
#Display all column names

df.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA', 'Location'],
#       dtype='object')

# %%
#Display total of raw data rows count and toal of columns count
df.shape
# Out:
# (296585, 27)

# %%
#Dispaly all columns data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296585 entries, 0 to 296584
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CAMIS                  296585 non-null  int64
#  1   DBA                    296583 non-null  object
#  2   BORO                   296585 non-null  object
#  3   BUILDING               295608 non-null  object
#  4   STREET                 296571 non-null  object
#  5   ZIPCODE                293427 non-null  float64
#  6   PHONE                  296505 non-null  object
#  7   CUISINE DESCRIPTION    293024 non-null  object
#  8   INSPECTION DATE        296585 non-null  object
#  9   ACTION                 293120 non-null  object
#  10  VIOLATION CODE         290763 non-null  object
#  11  VIOLATION DESCRIPTION  290763 non-null  object
#  12  CRITICAL FLAG          296585 non-null  object
#  13  SCORE                  279546 non-null  float64
#  14  GRADE                  146094 non-null  object
#  15  GRADE DATE             136548 non-null  object
#  16  RECORD DATE            296585 non-null  object
#  17  INSPECTION TYPE        293120 non-null  object
#  18  Latitude               294984 non-null  float64
#  19  Longitude              294984 non-null  float64
#  20  Community Board        291866 non-null  float64
#  21  Council District       291896 non-null  float64
#  22  Census Tract           291896 non-null  float64
#  23  BIN                    290674 non-null  float64
#  24  BBL                    294984 non-null  float64
#  25  NTA                    291866 non-null  object
#  26  Location               291866 non-null  object
# dtypes: float64(9), int64(1), object(17)
# memory usage: 61.1+ MB

# %%
#Checking how many miss values in each columns

df.isna().sum()
# Out:
# CAMIS                         0
# DBA                           2
# BORO                          0
# BUILDING                    977
# STREET                       14
# ZIPCODE                    3158
# PHONE                        80
# CUISINE DESCRIPTION        3561
# INSPECTION DATE               0
# ACTION                     3465
# VIOLATION CODE             5822
# VIOLATION DESCRIPTION      5822
# CRITICAL FLAG                 0
# SCORE                     17039
# GRADE                    150491
# GRADE DATE               160037
# RECORD DATE                   0
# INSPECTION TYPE            3465
# Latitude                   1601
# Longitude                  1601
# Community Board            4719
# Council District           4689
# Census Tract               4689
# BIN                        5911
# BBL                        1601
# NTA                        4719
# Location                   4719
# dtype: int64

# %%
#Keeping only needed columns

df = df[['BORO', 'CUISINE DESCRIPTION', 'GRADE', 'SCORE']]

#Drop missing value rows
df = df.dropna()

#keeping only valide grades

df = df[df['GRADE'].isin(['A', 'B', 'C', 'P' ])]

# %%
#showing data with only needed columns

df.head(10)
# Out:
#           BORO CUISINE DESCRIPTION GRADE  SCORE
# 6     Brooklyn             Chinese     P    0.0
# 9     Brooklyn            American     P    0.0
# 17           0            American     A   12.0
# 44    Brooklyn             Mexican     P    0.0
# 56   Manhattan               Other     A    0.0
# 66      Queens          Hamburgers     A    0.0
# 102     Queens             Chicken     A   13.0
# 104   Brooklyn    Eastern European     P    0.0
# 113  Manhattan      Latin American     A   12.0
# 115     Queens           Pakistani     A    9.0

# %%
#Counting total row after dropping missing value rows

df.shape
# Out:
# (132300, 4)

# %%
#Visualizaion: Compare Arrests: Manhattan vs. Brooklyn

#Prepare plot

grade_counts = df['GRADE'].value_counts()

grade_counts.plot(kind='bar')
plt.title("Restaurant Grade A, B, C, P")
plt.xlabel("GRADE")
plt.ylabel("Number of Restaurants")
plt.show()



#Conclusion : Most restaurants get A. Grade B and C are much fewer.

# %%
#Borough Comarison

boro_counts = df['BORO'].value_counts()

boro_counts.plot(kind='bar')
plt.title("Number of Restaurants by Borough")
plt.xlabel("Borough")
plt.ylabel("Counts")
plt.show()

#Conclusion : Manhattan has most the restaurants, Stanten Island has the least restaurants.

# %%
#Top Cusine Type

top_cuisine = df['CUISINE DESCRIPTION'].value_counts().head(10)

top_cuisine.plot(kind='bar')
plt.title("Top 10 Cusine Types")
plt.xlabel("Cusine Type")
plt.ylabel("Counts")
plt.show()

#Conclusion : American cuisine is the most cuisine type in the New York City.
